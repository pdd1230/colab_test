# %% [markdown]
# <a href="https://colab.research.google.com/github/pdd1230/colab_test/blob/main/Hello_World.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# **굵은 텍스트**
# *이탤릭체 텍스트*
# # 새 섹션
#
#
# ```
# # 코드로 형식 지정됨
# ```
# [네이버](https://naver.com)
# ![00.파이썬설치 및 설정_01_새파일생성.PNG]()
#
#
# > 인용구 추가
#
#
# 1.   항목 추가
# 2.   항목 추가
#
#
#
# *   항목 추가
# *   항목 추가
#
#
#
# ---
#
# \:
#
# :

# %%
a = [10, 20, 30]                  # list
b = (10, 20, 30)                  # tuple
c = {10, 20, 30}                  # set
d = {"name": "kim", "age": 20}    # dict

print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'list'>
# <class 'tuple'>
# <class 'set'>
# <class 'dict'>

# %%
import numpy as np

a = np.array([10, 20, 30])

# ndarray → 수치 계산을 위한 배열
print(a)
print(type(a))
# Out:
# [10 20 30]
# <class 'numpy.ndarray'>
